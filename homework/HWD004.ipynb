# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定資料夾位置與檔案名稱
folder = 'D:\shiang\MyCode\Github\ML100Days\homework\data'
file_name = 'application_train.csv'
file_path = os.path.join(folder,file_name)
rawdata = pd.read_csv(file_path)

# %%
# 前n列 or 後 n 列
n = 10
rawdata.head(n)
rawdata.tail(n)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 307501      456245       0         Cash loans           F            N
# 307502      456246       0         Cash loans           F            N
# 307503      456247       0         Cash loans           F            N
# 307504      456248       0         Cash loans           F            N
# 307505      456249       0         Cash loans           F            N
# 307506      456251       0         Cash loans           M            N
# 307507      456252       0         Cash loans           F            N
# 307508      456253       0         Cash loans           F            N
# 307509      456254       1         Cash loans           F            N
# 307510      456255       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 307501               Y             3           81000.0    269550.0
# ...

# %%
### get row/col count
(nrow,ncol) = rawdata.shape
print('The row count of application_train.csv is %s' %(nrow))
print('The column count of application_train.csv is %s' %(ncol))
# Out:
# The row count of application_train.csv is 307511
# The column count of application_train.csv is 122

# %%
# Get column name
print('The column names are as below :')
for col in rawdata.columns:
    print(col)
# Out:
# The column names are as below :
# SK_ID_CURR
# TARGET
# NAME_CONTRACT_TYPE
# CODE_GENDER
# FLAG_OWN_CAR
# FLAG_OWN_REALTY
# CNT_CHILDREN
# AMT_INCOME_TOTAL
# AMT_CREDIT
# AMT_ANNUITY
# AMT_GOODS_PRICE
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# NAME_HOUSING_TYPE
# REGION_POPULATION_RELATIVE
# DAYS_BIRTH
# DAYS_EMPLOYED
# DAYS_REGISTRATION
# DAYS_ID_PUBLISH
# OWN_CAR_AGE
# FLAG_MOBIL
# FLAG_EMP_PHONE
# FLAG_WORK_PHONE
# FLAG_CONT_MOBILE
# FLAG_PHONE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# REGION_RATING_CLIENT
# REGION_RATING_CLIENT_W_CITY
# WEEKDAY_APPR_PROCESS_START
# HOUR_APPR_PROCESS_START
# REG_REGION_NOT_LIVE_REGION
# REG_REGION_NOT_WORK_REGION
# LIVE_REGION_NOT_WORK_REGION
# REG_CITY_NOT_LIVE_CITY
# REG_CITY_NOT_WORK_CITY
# LIVE_CITY_NOT_WORK_CITY
# ORGANIZATION_TYPE
# EXT_SOURCE_1
# EXT_SOURCE_2
# EXT_SOURCE_3
# APARTMENTS_AVG
# BASEMENTAREA_AVG
# YEARS_BEGINEXPLUATATION_AVG
# YEARS_BUILD_AVG
# COMMONAREA_AVG
# ELEVATORS_AVG
# ...

# %%
# Filiter Data by Some Condition
# Select Column
col3_a = rawdata[['SK_ID_CURR','TARGET','CODE_GENDER']]
col3_b = rawdata[rawdata.columns[[0,1,2]]]
print(col3_a.head())
print(col3_b.head())
#
# Out:
#    SK_ID_CURR  TARGET CODE_GENDER
# 0      100002       1           M
# 1      100003       0           F
# 2      100004       0           M
# 3      100006       0           F
# 4      100007       0           M
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE
# 0      100002       1         Cash loans
# 1      100003       0         Cash loans
# 2      100004       0    Revolving loans
# 3      100006       0         Cash loans
# 4      100007       0         Cash loans

# %%
# 選取第二列第三欄的元素
rawdata.iloc[1,3]

# 選取第一二列
rawdata.iloc[[0,1],:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-4c16609bcb50> in <module>
#       6
#       7 # 選取
# ----> 8 rowdata.iloc[rawdata['CODE_GENDER']=='M',:]
#
# NameError: name 'rowdata' is not defined

# %%
# 選取 CODE_GENDER 為 M 且 NAME_CONTRACT_TYPE 為 'Cash loans'的列
filter1 = rawdata['CODE_GENDER']=='M'
filter2 = rawdata['NAME_CONTRACT_TYPE'] == 'Cash loans'
rawdata[ filter1 & filter2 ]
## or
# rawdata[ (rawdata['CODE_GENDER']=='M') & (rawdata['NAME_CONTRACT_TYPE'] == 'Cash loans') ]
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 4           100007       0         Cash loans           M            N
# 5           100008       0         Cash loans           M            N
# 7           100010       0         Cash loans           M            Y
# 13          100017       0         Cash loans           M            Y
# 15          100019       0         Cash loans           M            Y
# 16          100020       0         Cash loans           M            N
# 24          100029       0         Cash loans           M            Y
# 27          100032       0         Cash loans           M            N
# 28          100033       0         Cash loans           M            Y
# 33          100039       0         Cash loans           M            Y
# 37          100044       0         Cash loans           M            N
# ...

# %%
groups = ["Modern Web", "DevOps", "Cloud", "Big Data", "Security", "自我挑戰組"]
ironmen = [59, 9, 19, 14, 6, 77]

ironmen_dict = {
                "groups": groups,
                "ironmen": ironmen
}

# 建立 data frame
ironmen_df = pd.DataFrame(ironmen_dict)

filter = ironmen_df["ironmen"] > 10 # 參賽人數大於 10
ironmen_df[filter] # 篩選 data frame
# Out:
#        groups  ironmen
# 0  Modern Web       59
# 2       Cloud       19
# 3    Big Data       14
# 5       自我挑戰組       77

# %%
# filter 函數用於 欄名or列名 的 filter
rawdata.filter(like="CODE",axis=1)
# Out:
#        CODE_GENDER
# 0                M
# 1                F
# 2                M
# 3                F
# 4                M
# 5                M
# 6                F
# 7                M
# 8                F
# 9                M
# 10               F
# 11               F
# 12               F
# 13               M
# 14               F
# 15               M
# 16               M
# 17               F
# 18               F
# 19               F
# 20               M
# 21               F
# 22               F
# 23               F
# 24               M
# 25               F
# 26               F
# 27               M
# 28               M
# 29               M
# ...            ...
# 307481           M
# 307482           F
# 307483           F
# 307484           F
# 307485           F
# 307486           F
# 307487           M
# 307488           F
# 307489           F
# 307490           M
# 307491           M
# 307492           M
# 307493           F
# 307494           M
# 307495           M
# ...
